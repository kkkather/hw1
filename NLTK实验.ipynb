# %%
#分句
from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."
print(sent_tokenize(EXAMPLE_TEXT))
print(type(EXAMPLE_TEXT))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and Python is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]
# <class 'str'>

# %%
#分词
from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "His attitude to employees is an obvious example of his counter-cultural approach. For a futurist, Mr Musk is a very old-fashioned boss. He doesn’t like remote work. Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week. Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted."
print('分句结果为：',sent_tokenize(EXAMPLE_TEXT))
print('分词结果为：',word_tokenize(EXAMPLE_TEXT))
# Out:
# 分句结果为： ['His attitude to employees is an obvious example of his counter-cultural approach.', 'For a futurist, Mr Musk is a very old-fashioned boss.', 'He doesn’t like remote work.', 'Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week.', 'Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted.']
# ...

# %%
#停止词
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
#停止词
from nltk.corpus import stopwords
print(stopwords.words())
# Out:
# ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين', 'بيد', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما', 'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا', 'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا', 'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير', 'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها',
# ...

# %%
#停止词
from nltk.corpus import stopwords
print(stopwords.words('Chinese'))
# Out:
# ['一', '一下', '一些', '一切', '一则', '一天', '一定', '一方面', '一旦', '一时', '一来', '一样', '一次', '一片', '一直', '一致', '一般', '一起', '一边', '一面', '万一', '上下', '上升', '上去', '上来', '上述', '上面', '下列', '下去', '下来', '下面', '不一', '不久', '不仅', '不会', '不但', '不光', '不单', '不变', '不只', '不可', '不同', '不够', '不如', '不得', '不怕', '不惟', '不成', '不拘', '不敢', '不断', '不是', '不比', '不然', '不特', '不独', '不管', '不能', '不要', '不论', '不足', '不过', '不问', '与', '与其', '与否', '与此同时', '专门', '且', '两者', '严格', '严重', '个', '个人', '个别', '中小', '中间', '丰富', '临', '为', '为主', '为了', '为什么', '为什麽', '为何', '为着', '主张', '主要', '举行', '乃', '乃至', '么', '之', '之一', '之前', '之后', '之後', '之所以', '之类', '乌乎', '乎', '乘', '也', '也好', '也是', '也罢', '了', '了解', '争取', '于', '于是', '于是乎', '云云', '互相', '产生', '人们', '人家', '什么', '什么样', '什麽', '今后', '今天', '今年', '今後', '仍然', '从', '从事', '从而', '他', '他人', '他们', '他的', '代替', '以', '以上', '以下', '以为', '以便', '以免', '以前', '以及', '以后', '以外', '以後', '以来', '以至', '以至于', '以致', '们', '任', '任何', '任凭', '任务', '企图', '伟大', '似乎', '似的', '但', '但是', '何', '何况', '何处', '何时', '作为', '你', '你们', '你的', '使得', '使
# ...

# %%
import nltk
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
#删除停止词
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
example_sent = "His attitude to employees is an obvious example of his counter-cultural approach. For a futurist, Mr Musk is a very old-fashioned boss. He doesn’t like remote work. Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week. Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted."
stop_words = set(stopwords.words('english'))#停止词
word_tokens = word_tokenize(example_sent)#分词后
filtered_sentence=[]
for w in word_tokens:#循环遍历，如果不属于停止词，则加入到过滤后的句子列表中
    if w not in stop_words:
        filtered_sentence.append(w)
print('删除停用词后结果为：',filtered_sentence)
# Out:
# 删除停用词后结果为： ['His', 'attitude', 'employees', 'obvious', 'example', 'counter-cultural', 'approach', '.', 'For', 'futurist', ',', 'Mr', 'Musk', 'old-fashioned', 'boss', '.', 'He', '’', 'like', 'remote', 'work', '.', 'Earlier', 'year', 'sent', 'email', 'employees', 'Tesla', 'demanding', 'come', 'office', 'least', '40', 'hours', 'week', '.', 'Anyone', 'thought', 'antiquated', 'could', '“', 'pretend', 'work', 'somewhere', 'else', '”', ',', 'tweeted', '.']

# %%
#删除标点符号
import string
example_sent = "His attitude to employees is an obvious example of his counter-cultural approach. For a futurist, Mr Musk is a very old-fashioned boss. He doesn’t like remote work. Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week. Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted."
filtered_sentence = example_sent.translate(str.maketrans(string.punctuation, " " * len(string.punctuation))) 
print('删除标点符号后结果为：',filtered_sentence)
# Out:
# 删除停用词后结果为： His attitude to employees is an obvious example of his counter cultural approach  For a futurist  Mr Musk is a very old fashioned boss  He doesn’t like remote work  Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week  Anyone who thought this was antiquated could “pretend to work somewhere else”  he tweeted

# %%
import nltk
from urllib import request
# how to open and read the message from a website
url = '<http://www.gutenberg.org/files/1342/1342-0.txt>' #Pride and Prejudice
open_url = request.urlopen(url)
text = open_url.read().decode('utf8')
#print(text)

# %%
import nltk
import matplotlib
from nltk.util import bigrams
document = open('时间简史chapter1.txt',encoding='gb18030').read()
token = nltk.word_tokenize(document) #the document that you want to analyze.
edited_version = nltk.Text(token)

# %%
# 单词搜索
print('单词搜索')
edited_version.concordance('universe')
# Out:
# 单词搜索
# Displaying 25 of 47 matches:
# cellent . you are ready to start a universe . i ’ m assuming of course that yo
#  you wish to build an inflationary universe . if you ’ d prefer instead to bui
#  old-fashioned , standard big bang universe , you ’ ll need additional materia
# arity there is no where . when the universe begins to expand , it won ’ t be s
# from . and so , from nothing , our universe begins . in a single blinding puls
# hysics . in less than a minute the universe is a million billion miles across
# r be has been produced . we have a universe . it is a place of the most wondro
# d . they had found the edge of the universe , or at least the visible part of
# ted . in his book the inflationary universe , a lan guth provides an analogy t
#  of peering into the depths of the universe as like looking down from the hund
#  our acquaintance with the visible universe to within half an inch of the side
# ...

# %%
# 相似词搜索
print('相似词搜索')
edited_version.similar('time')
# Out:
# 相似词搜索
# moment center grasp them number space universe edge creation kind even
# right form notion wilson dish vastness microwaves distance depths

# %%
#上下文搜索
edited_version.concordance(word='atom',width=20,lines=10)#atom 的上下文，打印宽度20字符，共10行的上下文
#共同上下文搜索
edited_version.common_contexts(['minute','second'])#研究两个或两个以上的词共同的上下文
# Out:
# Displaying 2 of 2 matches:
# t of an atom , which
# out one atom in a hu
# No common contexts were found

# %%
#基于文章生成新的随机文本
edited_version.generate()
# Out:
# of a moment after the moment of creation . , spread through the mighty
# span of eternity , and much of what we know , or whether it has just
# lately popped into being , like a badly erected tent , without
# precisely the right moment . enough to know that for sure ; we can ’ t
# produce them . and night , through every season . to grasp just how
# tiny , tiny space about an ounce of matter . by doing a lot of math
# and watching carefully what goes on in particle accelerators ,
# scientists believe
# Building ngram index...
# ...

# %%
# 词汇分布表
edited_version.dispersion_plot(['universe', 'big', 'bang', 'space'])

# %%
from nltk.probability import *
from nltk.corpus import stopwords
import string


token = nltk.word_tokenize(document) #the document that you want to analyze.
edited_version = nltk.Text(token)


document1= document.translate(str.maketrans(string.punctuation, " " * len(string.punctuation))) #去标点符号1


token = nltk.word_tokenize(document1) #the document that you want to analyze.
token1=nltk.Text(token)
stop_words =set(stopwords.words())#停止词
filtered_version=[]
for w in token1:#循环遍历，如果不属于停止词，则加入到过滤后的句子列表中
    if w not in stop_words:
        filtered_version.append(w)


fdist = FreqDist(filtered_version)
vocabulary = fdist.keys()

# %%
fdist.plot(20, cumulative = True)#统计前20个高频词并绘制累积图
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
fdist.plot(20)#统计前20个高频词
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
fdist.tabulate(10)
# Out:
# universe        ’      000      big     bang        “        ”    space       10     time
#       48       43       23       21       20       18       18       15       14       13

# %%
print(fdist.most_common(3))#频数最大的前3项数据
print(fdist.max())#出现频率最多的数据
print(fdist.hapaxes())#出现频率最少的数据
# Out:
# [('universe', 48), ('’', 43), ('000', 23)]
# universe
# ...

# %%
print(fdist.hapaxes())
# Out:
# ['HOW', 'TO', 'BUILD', 'A', 'UNIVERSENO', 'MATTER', 'hard', 'grasp', 'spatially', 'unassuming', 'infinitesimal', 'insubstantial', 'dib', 'ink', 'gion', 'seconds', 'contained', 'exceedingly', 'microscopic', 'shrinking', 'billionth', 'normal', 'enormous', 'pack', 'ounce', 'excellent', 'assuming', 'prefer', 'fashioned', 'materials', 'gather', 'mote', 'squeeze', 'infinitesimally', 'compact', 'naturally', 'safe', 'observe', 'spectacle', 'expand', 'spreading', 'fill', 'emptiness', 'creates', 'natural', 'wrong', 'visualize', 'pregnant', 'hanging', 'dark', 'occupy', 'there—whether', 'popped', 'quietly', 'awaiting', 'emerge', 'blinding', 'pulse', 'glory', 'swift', 'expansive', 'words', 'assumes', 'heavenly', 'conception', 'lively', 'devote', 'careers', 'shaving', 'finer', 'wafers', 'forces', 'minute', 'growing', 'fast', 'degrees', 'reactions', 'create', 'elements—principally', 'dash', 'wondrous', 'gratifying', 'possibility', 'beautiful', 'takes', 'sandwich', 'debate', 'argued', 'ago', 'consen
# ...

# %%
print(fdist.max())
# Out:
# universe

# %%
# 二元语法
words = list(bigrams(edited_version))
print(words)
# Out:
# [('1', 'HOW'), ('HOW', 'TO'), ('TO', 'BUILD'), ('BUILD', 'A'), ('A', 'UNIVERSENO'), ('UNIVERSENO', 'MATTER'), ('MATTER', 'how'), ('how', 'hard'), ('hard', 'you'), ('you', 'try'), ('try', 'you'), ('you', 'will'), ('will', 'never'), ('never', 'be'), ('be', 'able'), ('able', 'to'), ('to', 'grasp'), ('grasp', 'just'), ('just', 'how'), ('how', 'tiny'), ('tiny', ','), (',', 'how'), ('how', 'spatially'), ('spatially', 'unassuming'), ('unassuming', ','), (',', 'is'), ('is', 'a'), ('a', 'proton'), ('proton', '.'), ('.', 'it'), ('it', 'is'), ('is', 'just'), ('just', 'way'), ('way', 'too'), ('too', 'small'), ('small', '.'), ('.', 'a'), ('a', 'proton'), ('proton', 'is'), ('is', 'an'), ('an', 'infinitesimal'), ('infinitesimal', 'part'), ('part', 'of'), ('of', 'an'), ('an', 'atom'), ('atom', ','), (',', 'which'), ('which', 'is'), ('is', 'itself'), ('itself', 'of'), ('of', 'course'), ('course', 'an'), ('an', 'insubstantial'), ('insubstantial', 'thing'), ('thing', '.'), ('.', 'protons'), ('protons',
# ...

# %%
words = list(trigrams(edited_version))
print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 words = list(trigrams(edited_version))
#       2 print(words)
#
# NameError: name 'trigrams' is not defined

# %%
# 词汇计数
print(len(edited_version))#文本总字数
sorted(set(edited_version))
print(len(set(edited_version)))#文本除去重复词语计数
print(len(edited_version) / len(set(edited_version)))#重复词密度
# Out:
# 4260
# 1146
# 3.717277486910995

# %%
print(edited_version.count("universe"))#特定词汇计数
print(edited_version.count('universe') * 100 / len(edited_version))#关键词密度
# Out:
# 47
# 1.1032863849765258

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()
example_words = ["python","pythoner","pythoning","pythoned","pythonly"]
for w in example_words:
    print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %%
#基于Porter词干提取算法
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()
print(porter_stemmer.stem('acupuncture'))
 
#基于Lancaster 词干提取算法 
from nltk.stem.lancaster import LancasterStemmer
lancaster_stemmer = LancasterStemmer()
print(lancaster_stemmer.stem('acupuncture'))       
 
#基于Snowball 词干提取算法 
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer("english")
print(snowball_stemmer.stem('acupuncture'))
# Out:
# acupunctur
# acupunct
# acupunctur

# %%
#对句子进行词干提取
EXAMPLE_TEXT = "His attitude to employees is an obvious example of his counter-cultural approach. For a futurist, Mr Musk is a very old-fashioned boss. He doesn’t like remote work. Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week. Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted."
words = word_tokenize(EXAMPLE_TEXT)

for w in words:
    print(porter_stemmer .stem(w))
# Out:
# hi
# attitud
# to
# employe
# is
# an
# obviou
# exampl
# of
# hi
# counter-cultur
# approach
# .
# for
# a
# futurist
# ,
# mr
# musk
# is
# a
# veri
# old-fashion
# boss
# .
# he
# doesn
# ’
# t
# like
# remot
# work
# .
# earlier
# thi
# year
# he
# sent
# an
# email
# to
# employe
# at
# tesla
# demand
# that
# they
# come
# to
# the
# offic
# for
# at
# least
# 40
# hour
# a
# week
# .
# anyon
# who
# thought
# thi
# wa
# antiqu
# could
# “
# pretend
# to
# work
# somewher
# els
# ”
# ,
# he
# tweet
# .

# %%
from nltk.tag import pos_tag
EXAMPLE_TEXT = "His attitude to employees is an obvious example of his counter-cultural approach. For a futurist, Mr Musk is a very old-fashioned boss. He doesn’t like remote work. Earlier this year he sent an email to employees at Tesla demanding that they come to the office for at least 40 hours a week. Anyone who thought this was antiquated could “pretend to work somewhere else”, he tweeted."
words = word_tokenize(EXAMPLE_TEXT)
print(pos_tag(words))
# Out:
# [('His', 'PRP$'), ('attitude', 'NN'), ('to', 'TO'), ('employees', 'NNS'), ('is', 'VBZ'), ('an', 'DT'), ('obvious', 'JJ'), ('example', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('counter-cultural', 'JJ'), ('approach', 'NN'), ('.', '.'), ('For', 'IN'), ('a', 'DT'), ('futurist', 'NN'), (',', ','), ('Mr', 'NNP'), ('Musk', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('very', 'RB'), ('old-fashioned', 'JJ'), ('boss', 'NN'), ('.', '.'), ('He', 'PRP'), ('doesn', 'VBZ'), ('’', 'JJ'), ('t', 'NNS'), ('like', 'IN'), ('remote', 'JJ'), ('work', 'NN'), ('.', '.'), ('Earlier', 'RBR'), ('this', 'DT'), ('year', 'NN'), ('he', 'PRP'), ('sent', 'VBD'), ('an', 'DT'), ('email', 'NN'), ('to', 'TO'), ('employees', 'NNS'), ('at', 'IN'), ('Tesla', 'NNP'), ('demanding', 'VBG'), ('that', 'IN'), ('they', 'PRP'), ('come', 'VBP'), ('to', 'TO'), ('the', 'DT'), ('office', 'NN'), ('for', 'IN'), ('at', 'IN'), ('least', 'JJS'), ('40', 'CD'), ('hours', 'NNS'), ('a', 'DT'), ('week', 'NN'), ('.', '.'), ('Anyone', 'NN'), ('who', 'WP'), 
# ...

# %%
import nltk
from nltk.corpus import brown

# 划分训练集和测试集
tagged_sents = brown.tagged_sents(categories='news')
size = int(len(tagged_sents) * 0.9)
train_sets = tagged_sents[:size]
test_sets = tagged_sents[size:]

# 训练标注器，并把它们组合起来
t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train=train_sets, backoff=t0)
t2 = nltk.BigramTagger(train=train_sets, backoff=t1)

# 查看标注器性能
# 0.9735641453364413
print(t2.evaluate(train_sets))
# 0.8459085019435861
print(t2.evaluate(test_sets))
# Out:
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/2241222981.py:17: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(t2.evaluate(train_sets))
# 0.9736193811380784
# 0.8452108043456593
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/2241222981.py:19: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(t2.evaluate(test_sets))

# %%
#删去停用词后
from nltk.tag import pos_tag
EXAMPLE_TEXT = "His attitude employees obvious example counter-cultural approach. For  futurist, Mr Musk old-fashioned boss. He like remote work. Earlier year sent email employees Tesla demanding come office least 40 hours week. Anyone thought antiquated could “pretend  work somewhere else”, he tweeted."
words = word_tokenize(EXAMPLE_TEXT)
print(pos_tag(words))
# Out:
# [('His', 'PRP$'), ('attitude', 'NN'), ('employees', 'NNS'), ('obvious', 'JJ'), ('example', 'NN'), ('counter-cultural', 'JJ'), ('approach', 'NN'), ('.', '.'), ('For', 'IN'), ('futurist', 'NN'), (',', ','), ('Mr', 'NNP'), ('Musk', 'NNP'), ('old-fashioned', 'JJ'), ('boss', 'NN'), ('.', '.'), ('He', 'PRP'), ('like', 'IN'), ('remote', 'JJ'), ('work', 'NN'), ('.', '.'), ('Earlier', 'RBR'), ('year', 'NN'), ('sent', 'VBD'), ('email', 'NN'), ('employees', 'NNS'), ('Tesla', 'VBP'), ('demanding', 'VBG'), ('come', 'JJ'), ('office', 'NN'), ('least', 'JJS'), ('40', 'CD'), ('hours', 'NNS'), ('week', 'NN'), ('.', '.'), ('Anyone', 'NNP'), ('thought', 'VBD'), ('antiquated', 'VBN'), ('could', 'MD'), ('“', 'VB'), ('pretend', 'JJ'), ('work', 'NN'), ('somewhere', 'RB'), ('else', 'RB'), ('”', 'NN'), (',', ','), ('he', 'PRP'), ('tweeted', 'VBD'), ('.', '.')]

# %%
#词性标注 组合标注器
from nltk.corpus import brown
from nltk.tag import UnigramTagger
from nltk.tag import DefaultTagger#
from nltk.tag import BigramTagger
from nltk.tag import TrigramTagger
brown_tagged_sents = brown.tagged_sents(categories='news')
default_tagger = nltk.DefaultTagger('NN')
train_data=brown_tagged_sents[:int(len(brown_tagged_sents)*0.9)]
test_data=brown_tagged_sents[int(len(brown_tagged_sents)*0.9):]
#backoff是指当不能进行正确的标签预测时会咨询backoff
#一元模型
unigram_tagger=UnigramTagger(train_data,backoff=default_tagger)
print(unigram_tagger.evaluate(test_data))
#二元模型
bigram_tagger=BigramTagger(train_data,backoff=unigram_tagger)
print(bigram_tagger.evaluate(test_data))
#三元模型
trigram_tagger= TrigramTagger(train_data,backoff=bigram_tagger) 
print(trigram_tagger.evaluate(test_data))
# Out:
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/2828892599.py:13: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(unigram_tagger.evaluate(test_data))
# 0.8361407355726104
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/2828892599.py:16: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(bigram_tagger.evaluate(test_data))
# 0.8452108043456593
# 0.843317053722715
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/2828892599.py:19: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(trigram_tagger.evaluate(test_data))

# %%
#词性标注 ngram标注器
from nltk.corpus import brown
from nltk.tag import UnigramTagger#一元模型标注，只考虑条件概率
from nltk.tag import BigramTagger#会考虑给定单词和该单词前一个单词
from nltk.tag import TrigramTagger#与前面两个都有关
brown_tagged_sents = brown.tagged_sents(categories='news')#brown数据集
#为判断标注器是否过拟合分离训练集和测试集，90%作为训练集，10%作为测试集
train_data=brown_tagged_sents[:int(len(brown_tagged_sents) * 0.9)]
test_data=brown_tagged_sents[int(len(brown_tagged_sents) * 0.9):]
#一元模型
unigram_tagger=UnigramTagger(train_data)
print(unigram_tagger.evaluate(train_data))
print(unigram_tagger.evaluate(test_data))
#二元模型
bigram_tagger=BigramTagger(train_data)
print(bigram_tagger.evaluate(train_data))
print(bigram_tagger.evaluate(test_data))
#三元模型
trigram_tagger= TrigramTagger(train_data) 
print(trigram_tagger.evaluate(train_data))
print(trigram_tagger.evaluate(test_data))
# Out:
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/1786363372.py:11: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(unigram_tagger.evaluate(train_data))
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/1786363372.py:12: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(unigram_tagger.evaluate(test_data))
# 0.9353630649241612
# 0.8121200039868434
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/1786363372.py:15: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(bigram_tagger.evaluate(train_data))
# 0.7884137382485832
# 0.10206319146815508
# /var/folders/pg/05k_m5bx5klc38zykxqwjqz40000gn/T/ipykernel_59824/1786363372.py:16: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
# ...

# %%
# 分词
EXAMPLE_TEXT = "His attitude to employees is an obvious example of his counter-cultural approach"
words = word_tokenize(EXAMPLE_TEXT)
# 词性标注
sentence_tag = nltk.pos_tag(words)
print(sentence_tag)
# 定义分块语法
# NNP(专有名词) PRP$(格代名词)
# 第一条规则匹配可选的词（限定词或格代名词），零个或多个形容词，然后跟一个名词
# 第二条规则匹配一个或多个专有名词
# $符号是正则表达式中的一个特殊字符，必须使用转义符号\来匹配PP$
grammar = r"""
    NP: {<DT|PRP\$>?<JJ>*<NN>}
        {<NNP>+}
"""
# 进行分块
cp = nltk.RegexpParser(grammar)
tree = cp.parse(sentence_tag)
tree.draw()
# Out:
# [('His', 'PRP$'), ('attitude', 'NN'), ('to', 'TO'), ('employees', 'NNS'), ('is', 'VBZ'), ('an', 'DT'), ('obvious', 'JJ'), ('example', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('counter-cultural', 'JJ'), ('approach', 'NN')]

# %%
import nltk
import random
from nltk import NaiveBayesClassifier
from nltk.stem.lancaster import LancasterStemmer

#自定义提取词尾函数
def suffix(word):
 lancaster_stemmer = LancasterStemmer()
 stem = lancaster_stemmer.stem(word)
 original = word
 suff = original .replace(stem, "")
 return suff

#从文件中读取单词数据
def word_data(file):
    words = []
    for line in open(words).readlines():
        word = line.strip()
        words.append(word)
    return words

Greek = [(suffix(word),'Greek') for word in word_data(file='words/Greek.txt')]
Latin = [(suffix(word),'Latin') for word in word_data(file='words/Latin.txt')]
words = (Greek+Latin)
random.shuffle(names)


featuresets = [(word,GreekOrLatin) for (word,GreekOrLatin) in words]
#将特征集分按5:1分为训练集和测试集
train_set, test_set = featuresets[500:],featuresets[:100]

#使用训练集训练分类器
classifier = NaiveBayesClassifier.train(train_set)
#测试分类器准确性
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 22>()
#      19         words.append(word)
#      20     return words
# ---> 22 Greek = [(suffix(word),'Greek') for word in word_data(file='words/Greek.txt')]
#      23 Latin = [(suffix(word),'Latin') for word in word_data(file='words/Latin.txt')]
#      24 words = (Greek+Latin)
#
# Input In [28], in word_data(file)
#      15 def word_data(file):
#      16     words = []
# ---> 17     for line in open(words).readlines():
#      18         word = line.strip()
#      19         words.append(word)
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
#词形还原
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("dogs"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("geese"))
print(lemmatizer.lemmatize("better", pos="a"))
print(lemmatizer.lemmatize("best", pos="a"))
print(lemmatizer.lemmatize("ran"))
print(lemmatizer.lemmatize("meaning",'v'))
# Out:
# dog
# cactus
# goose
# good
# best
# ran
# mean

# %%
import nltk
import random
from nltk.corpus import movie_reviews

documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

print(documents[1])

all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)
print(all_words.most_common(15))
print(all_words["stupid"])
# Out:
# (['with', 'his', 'last', 'two', 'films', '-', 'shine', 'and', 'snow', 'falling', 'on', 'cedars', '-', 'australian', 'director', 'scott', 'hicks', 'has', 'proven', 'his', 'cinematic', 'flashbacks', 'to', 'be', 'some', 'of', 'the', 'best', 'out', 'there', ',', 'and', 'his', 'latest', ',', 'hearts', 'in', 'atlantis', ',', 'is', 'no', 'different', '.', 'its', 'structure', '-', 'beginning', 'and', 'ending', 'in', 'present', 'day', 'with', 'one', 'long', 'flashback', 'in', 'the', 'middle', '-', 'is', 'similar', 'to', 'the', 'green', 'mile', ',', 'which', 'is', 'a', 'bit', 'ironic', 'considering', 'both', 'were', 'based', 'on', 'stephen', 'king', 'books', '.', 'the', 'parallels', 'don', "'", 't', 'end', 'there', ',', 'either', '.', 'atlantis', 'was', 'adapted', 'by', 'william', 'goldman', ',', 'who', 'had', 'previously', 'penned', 'the', 'big', '-', 'screen', 'version', 'of', 'misery', 'and', 'is', 'in', 'the', 'process', 'of', 'working', 'on', 'the', 'script', 'for', 'king', "'", 's', 'dre
# ...

# %%
#基于Lancaster 词干提取算法 
from nltk.stem.lancaster import LancasterStemmer
def suffix(word):
 lancaster_stemmer = LancasterStemmer()
 stem = lancaster_stemmer.stem(word)
 original = word
 suff = original .replace(stem, "")
 return suff

suffix('acupucture')
# Out:
# 'ure'
